# %% [markdown]
# <a href="https://colab.research.google.com/github/Maxxx-VS/The-Founder/blob/master/20_4_%D0%94%D0%BE%D0%BC%D0%B0%D1%88%D0%BD%D1%8F%D1%8F_%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0%22_(%D0%BF%D0%B8%D1%81%D0%B0%D1%82%D0%B5%D0%BB%D0%B8).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# В домашней работе необходимо выполнить следующее задание:
#
# 1. Подготовьте датасет с [писателями Русской литературы](https://storage.yandexcloud.net/academy.ai/russian_literature.zip) для обучения модели `Embedding` по аналогии с уроком [20.2](https://colab.research.google.com/drive/1KEFUgyBcqGaXGZEU-7MHENn5RH_AIvfH)
# 2. Подгрузите веса Наташи как в уроке [20.3](https://colab.research.google.com/drive/1g_dX1XpRY--X6EjFflCC0717p9_9Y1SP) для эмбендинга.
# 3. Заморозьте слой эмбединга.
# 4. Выберите любых 5 писателей и обучите модель на них, не забудьте про балансировку (предварительно выделите 10% датасета на проверочную выборку и 10% на тестовую). Выбирайте писателей с большими объемами текстов, что даст большее число примеров для обучения.
# 5. Добейтесь средней точности более 70% на тестовых образцах. Получите 3 балла.
# 6. Если сможете добиться точности более 85% получите 4 балла.
# 7. Хотите 5 баллов независимо от точности? Изучите самостоятельно и примените токенизатор [Razdel](https://github.com/natasha/razdel#usage) для данной задачи, вместо встроенного токенизатора для Keras.
#
# **Подсказка**. Так как проверка задания проводиться по средней точности на тестовых образцах (вычисляем по диагонали матрицы ошибок), то для улучшения данного показателя используйте колбэк функцию `keras.callbacks.ModelCheckpoint` из урока [19.2](https://colab.research.google.com/drive/1x2qd4MvG3ODgNrE2uqxRAZB70dGgdGft) для сохранения лучшей эпохи.
#
# **Подсказка 2**. Часто при работе с текстовыми данными вы можете заметить, что при использовании параметра `validation_split`, в методе `fit()`, точность на проверочной выборке ведет себя странно. В этом случае выделите проверочную выборку самостоятельно и используйте ее с помощью параметра `validation_data`.

# %%
# !wget https://storage.yandexcloud.net/natasha-navec/packs/navec_hudlit_v1_12B_500K_300d_100q.tar
# !pip install navec
# Out:
# --2024-10-12 07:36:30--  https://storage.yandexcloud.net/natasha-navec/packs/navec_hudlit_v1_12B_500K_300d_100q.tar
# Resolving storage.yandexcloud.net (storage.yandexcloud.net)... 213.180.193.243, 2a02:6b8::1d9
# Connecting to storage.yandexcloud.net (storage.yandexcloud.net)|213.180.193.243|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 53012480 (51M) [application/x-tar]
# Saving to: ‘navec_hudlit_v1_12B_500K_300d_100q.tar’
#
# navec_hudlit_v1_12B 100%[===================>]  50.56M  15.6MB/s    in 3.6s
#
# 2024-10-12 07:36:35 (14.1 MB/s) - ‘navec_hudlit_v1_12B_500K_300d_100q.tar’ saved [53012480/53012480]
#
# Collecting navec
#   Downloading navec-0.10.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from navec) (1.26.4)
# Downloading navec-0.10.0-py3-none-any.whl (23 kB)
# Installing collected packages: navec
# Successfully installed navec-0.10.0

# %%
from navec import Navec
navec = Navec.load('navec_hudlit_v1_12B_500K_300d_100q.tar')

import keras
data_path = keras.utils.get_file("russian_literature.zip", "https://storage.yandexcloud.net/academy.ai/russian_literature.zip")

# !unzip -qo "{data_path}" -d ./dataset
CLASS_LIST=["Dostoevsky", "Tolstoy", "Gorky", "Bryusov", "Turgenev"]
# Out:
# Downloading data from https://storage.yandexcloud.net/academy.ai/russian_literature.zip
# 21547079/21547079 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# error:  cannot create ./dataset/poems/Blok/╨б╤В╨╕╤Е╨╛╤В╨▓╨╛╤А╨╡╨╜╨╕╤П 1897-1903 ╨│╨│, ╨╜╨╡ ╨▓╨╛╤И╨╡╨┤╤И╨╕╨╡ ╨▓ ╨╛╤Б╨╜╨╛╨▓╨╜╨╛╨╡ ╤Б╨╛╨▒╤А╨░╨╜╨╕╨╡.txt
#         File name too long
# error:  cannot create ./dataset/prose/Gogol/╨Я╨╛╨▓╨╡╤Б╤В╤М ╨╛ ╤В╨╛╨╝, ╨║╨░╨║ ╨┐╨╛╤Б╤Б╨╛╤А╨╕╨╗╤Б╤П ╨Ш╨▓╨░╨╜ ╨Ш╨▓╨░╨╜╨╛╨▓╨╕╤З ╤Б ╨Ш╨▓╨░╨╜╨╛╨╝ ╨Э╨╕╨║╨╕╤Д╨╛╤А╨╛╨▓╨╕╤З╨╡╨╝.txt
#         File name too long
# error:  cannot create ./dataset/publicism/Tolstoy/╨Ф╨╛╨║╨╗╨░╨┤, ╨┐╤А╨╕╨│╨╛╤В╨╛╨▓╨╗╨╡╨╜╨╜╤Л╨╣ ╨┤╨╗╤П ╨║╨╛╨╜╨│╤А╨╡╤Б╤Б╨░ ╨╛ ╨╝╨╕╤А╨╡ ╨▓ ╨б╤В╨╛╨║╨│╨╛╨╗╤М╨╝╨╡.txt
#         File name too long
# error:  cannot create ./dataset/publicism/Tolstoy/╨Я╨╛╤З╨╡╨╝╤Г ╤Е╤А╨╕╤Б╤В╨╕╨░╨╜╤Б╨║╨╕╨╡ ╨╜╨░╤А╨╛╨┤╤Л ╨▓╨╛╨╛╨▒╤Й╨╡ ╨╕ ╨▓ ╨╛╤Б╨╛╨▒╨╡╨╜╨╜╨╛╤Б╤В╨╕ ╤А╤Г╤Б╤Б╨║╨╕╨╣ ╨╜╨░╤Е╨╛╨┤╤П╤В╤Б╤П ╤В╨╡╨┐╨╡╤А╤М ╨▓ ╨▒╨╡╨┤╤Б╤В╨▓╨╡╨╜╨╜╨╛╨╝ ╨┐╨╛╨╗╨╛╨╢╨╡╨╜╨╕╨╕.txt
#         File name too long

# %%
import glob # Вспомогательный модуль для работы с файловой системой

all_texts = {} # Собираем в словарь весь датасет

for author in CLASS_LIST:
    all_texts[author] = '' # Инициализируем пустой строкой новый ключ словаря
    for path in glob.glob('./dataset/prose/{}/*.txt'.format(author)) +  glob.glob('./dataset/poems/{}/*.txt'.format(author)): # Поиск файлов по шаблону
        with open(f'{path}', 'r', errors='ignore') as f: # игнорируем ошибки (например символы из другой кодировки)
            # Загрузка содержимого файла в строку
            text = f.read()

        all_texts[author]  += ' ' + text.replace('\n', ' ') # Заменяем символ перехода на новую строку пробелом

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

embedding_dim = 300    # размерность векторов эмбединга (300d в имени эмбединга)
max_words = 10000      # Количество слов, рассматриваемых как признаки

# Используется встроенный в Keras токенизатор для разбиения текста и построения частотного словаря
tokenizer = Tokenizer(num_words=max_words,
                      filters='!"#$%&()*+,-–—./…:;<=>?@[\\]^_`{|}~«»\t\n\xa0\ufeff',
                      lower=True, split=' ', char_level=False)

# Построение частотного словаря по текстам
tokenizer.fit_on_texts(all_texts.values())

# %%
seq_train = tokenizer.texts_to_sequences(all_texts.values())
seq_train_balance = [seq_train[cls][:100_000] for cls in range(len(CLASS_LIST))]

# %%
# используем генератор цикла для получения длины текстов по каждому автору
total = sum(len(i) for i in seq_train)
print(f'Датасет состоит из {total} слов')
# Out:
# Датасет состоит из 3843964 слов

# %%
import numpy as np

print('Общая выборка по писателям (по словам):')
mean_list = np.array([])
for author in CLASS_LIST:
    cls = CLASS_LIST.index(author)
    print(f'{author} - {len(seq_train_balance[cls])} слов, доля в общей базе: {len(seq_train_balance[cls])/total*100 :.2f}%')
    mean_list = np.append(mean_list, len(seq_train_balance[cls]))

print('Среднее значение слов: ', np.round(mean_list.mean()))
print('Медианное значение слов: ', np.median(mean_list))
# Out:
# Общая выборка по писателям (по словам):
# Dostoevsky - 100000 слов, доля в общей базе: 2.60%
# Tolstoy - 100000 слов, доля в общей базе: 2.60%
# Gorky - 100000 слов, доля в общей базе: 2.60%
# Bryusov - 100000 слов, доля в общей базе: 2.60%
# Turgenev - 100000 слов, доля в общей базе: 2.60%
# Среднее значение слов:  100000.0
# Медианное значение слов:  100000.0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
fig, ax = plt.subplots()
ax.pie([len(i) for i in seq_train_balance], # формируем список значений как длина символов текста каждого автора
       labels=CLASS_LIST,                    # список меток
       pctdistance=1.2,                      # дистанция размещения % (1 - граница окружности)
       labeldistance=1.4,                    # размещение меток (1 - граница окружности)
       autopct='%1.2f%%')                     # формат для % (2 знака после запятой)

plt.show()

# %%
WIN_SIZE = 1000   # Ширина окна в токенах
WIN_STEP = 100    # Шаг окна в токенах

# Функция разбиения последовательности на отрезки скользящим окном
# Последовательность разбивается на части до последнего полного окна
# Параметры:
# sequence - последовательность токенов
# win_size - размер окна
# step - шаг окна
def seq_split(sequence, win_size, step):
    # Делим строку на отрезки с помощью генератора цикла
    return [sequence[i:i + win_size] for i in range(0, len(sequence) - win_size + 1, step)]

def seq_vectorize(
    seq_list,   # Последовательность
    test_split, # Доля на тестовую сборку
    class_list, # Список классов
    win_size,   # Ширина скользящего окна
    step        # Шаг скользящего окна
):

    # Списки для результирующих данных
    x_train, y_train, x_test, y_test =  [], [], [], []

    # Пробежимся по всем классам:
    for class_item in class_list:
        # Получим индекс класса
        cls = class_list.index(class_item)

        # Пороговое значение индекса для разбивки на тестовую и обучающую выборки
        gate_split = int(len(seq_list[cls]) * (1-test_split))

        # Разбиваем последовательность токенов класса на отрезки
        vectors_train = seq_split(seq_list[cls][:gate_split], win_size, step) # последовательность до порога попадет в обучающую выборку
        vectors_test = seq_split(seq_list[cls][gate_split:], win_size, step)  # последовательность после порога попадет в тестовую выборку

        # Добавляем отрезки в выборку
        x_train += vectors_train
        x_test += vectors_test

        # Для всех отрезков класса добавляем метки класса в виде one-hot-encoding
        # Каждую метку берем len(vectors) раз, так она одинакова для всех выборок одного класса
        y_train += [keras.utils.to_categorical(cls, len(class_list))] * len(vectors_train)
        y_test += [keras.utils.to_categorical(cls, len(class_list))] * len(vectors_test)

    # Возвращаем результатов как numpy-массивов
    return np.array(x_train), np.array(y_train), np.array(x_test), np.array(y_test)

# %%
x_train, y_train, x_test, y_test = seq_vectorize(seq_train_balance, 0.1, CLASS_LIST, WIN_SIZE, WIN_STEP)

# %%
print(f'Форма входных данных для обучающей выборки: {x_train.shape}')
print(f'Форма выходных данных (меток) для обучающей выборки: {y_train.shape}')
print()
print(f'Форма входных данных для тестовой выборки: {x_test.shape}')
print(f'Форма выходных данных (меток) для тестовой выборки: {y_test.shape}')
# Out:
# Форма входных данных для обучающей выборки: (4455, 1000)
# Форма выходных данных (меток) для обучающей выборки: (4455, 5)
#
# Форма входных данных для тестовой выборки: (455, 1000)
# Форма выходных данных (меток) для тестовой выборки: (455, 5)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay # Для работы с матрицей ошибок

# Вывод графиков точности и ошибки
def show_plot(history):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 5))
    fig.suptitle('График процесса обучения модели')
    ax1.plot(history.history['accuracy'],
               label='График точности на обучающей выборке')
    ax1.plot(history.history['val_accuracy'],
               label='График точности на проверочной выборке')
    ax1.xaxis.get_major_locator().set_params(integer=True) # На оси х показываем целые числа
    ax1.set_xlabel('Эпоха обучения')
    ax1.set_ylabel('График точности')
    ax1.legend()

    ax2.plot(history.history['loss'],
               label='Ошибка на обучающей выборке')
    ax2.plot(history.history['val_loss'],
               label='Ошибка на проверочной выборке')
    ax2.xaxis.get_major_locator().set_params(integer=True) # На оси х показываем целые числа
    ax2.set_xlabel('Эпоха обучения')
    ax2.set_ylabel('Ошибка')
    ax2.legend()
    plt.show()

# Функция вывода предсказанных значений
def show_confusion_matrix(y_true, y_pred, class_labels):
    # Матрица ошибок
    cm = confusion_matrix(np.argmax(y_true, axis=1),
                          np.argmax(y_pred, axis=1),
                          normalize='true')
    # Округление значений матрицы ошибок
    cm = np.around(cm, 3)

    # Отрисовка матрицы ошибок
    fig, ax = plt.subplots(figsize=(10, 10))
    ax.set_title(f'Матрица ошибок', fontsize=18)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)
    disp.plot(ax=ax)
    plt.gca().images[-1].colorbar.remove()  # Убираем ненужную цветовую шкалу
    plt.xlabel('Предсказанные классы', fontsize=16)
    plt.ylabel('Верные классы', fontsize=16)
    fig.autofmt_xdate(rotation=45)          # Наклон меток горизонтальной оси
    plt.show()

    # Средняя точность распознавания определяется как среднее диагональных элементов матрицы ошибок
    print('\nСредняя точность распознавания: {:3.0f}%'.format(100. * cm.diagonal().mean()))

# %%
from keras.models import Sequential
from keras.layers import Embedding, Flatten, Dense, SpatialDropout1D, BatchNormalization, Dropout

model = Sequential()
model.add(Embedding(max_words, embedding_dim, input_length=WIN_SIZE))
model.add(BatchNormalization())
model.add(Dense(20, activation="relu"))
model.add(Dropout(0.6))

model.add(BatchNormalization())
model.add(Flatten())
model.add(Dense(len(CLASS_LIST), activation='softmax'))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
import numpy as np

word_index = tokenizer.word_index
embeddings_index = navec

embedding_matrix = np.zeros((max_words, embedding_dim))
for word, i in word_index.items():
    if i < max_words:
        embedding_vector = embeddings_index.get(word)
        if embedding_vector is not None:
            embedding_matrix[i] = embedding_vector

# %%
model.layers[0].set_weights([embedding_matrix])
model.layers[0].trainable = False
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-8a6fa6457695> in <cell line: 1>()
# ----> 1 model.layers[0].set_weights([embedding_matrix])
#       2 model.layers[0].trainable = False
#
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/layer.py in set_weights(self, weights)
#     675         layer_weights = self.weights
#     676         if len(layer_weights) != len(weights):
# --> 677             raise ValueError(
#     678                 f"You called `set_weights(weights)` on layer '{self.name}' "
#     679                 f"with a weight list of length {len(weights)}, but the layer "
#
# ValueError: You called `set_weights(weights)` on layer 'embedding_1' with a weight list of length 1, but the layer was expecting 0 weights.

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

callbacks = [keras.callbacks.ModelCheckpoint(filepath = 'best_model.keras',
                             monitor = 'val_acc',
                             save_best_only = True,
                             mode = 'max',
                             verbose = 0)]

history = model.fit(x_train, y_train, epochs=100, batch_size=256, validation_split=0.05)
# model.save_weights('pre_trained_model.h5') # можно сохранять не только модели, но и веса
# Out:
# Epoch 1/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 148ms/step - accuracy: 1.0000 - loss: 1.5510e-04 - val_accuracy: 0.4260 - val_loss: 1.8380
# Epoch 2/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 1.0000 - loss: 6.3481e-05 - val_accuracy: 0.5067 - val_loss: 1.6549
# Epoch 3/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 3.1389e-05 - val_accuracy: 0.5336 - val_loss: 1.6100
# Epoch 4/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 2.2716e-05 - val_accuracy: 0.4888 - val_loss: 1.7874
# Epoch 5/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 1.0000 - loss: 2.4012e-05 - val_accuracy: 0.4753 - val_loss: 1.9625
# Epoch 6/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 9.6282e-06 - val_accuracy: 0.4395 - val_loss: 2.1720
# Epoch 7/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 1.0000 - loss: 2.3124e-05 - val_accuracy: 0.3498 - val_loss: 2.6958
# Epoch 8/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 1.0000 - loss: 5.7178e-05 - val_accuracy: 0.3229 - val_loss: 3.2388
# Epoch 9/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 1.0000 - loss: 3.0700e-05 - val_accuracy: 0.4126 - val_loss: 2.4745
# Epoch 10/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 2.1222e-05 - val_accuracy: 0.3767 - val_loss: 2.6246
# Epoch 11/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 1.5563e-05 - val_accuracy: 0.3991 - val_loss: 2.4616
# Epoch 12/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 1.4302e-05 - val_accuracy: 0.4574 - val_loss: 2.0961
# Epoch 13/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 1.3688e-05 - val_accuracy: 0.4574 - val_loss: 2.0711
# Epoch 14/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 7.8533e-06 - val_accuracy: 0.4529 - val_loss: 2.1584
# Epoch 15/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 2.8283e-06 - val_accuracy: 0.4753 - val_loss: 2.2938
# Epoch 16/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 4.8850e-06 - val_accuracy: 0.4798 - val_loss: 2.1880
# Epoch 17/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 1.0000 - loss: 3.7586e-06 - val_accuracy: 0.4753 - val_loss: 2.1385
# Epoch 18/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 1.0000 - loss: 1.8387e-06 - val_accuracy: 0.4753 - val_loss: 2.0222
# Epoch 19/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 1.9880e-06 - val_accuracy: 0.4843 - val_loss: 1.9812
# Epoch 20/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 1.0779e-06 - val_accuracy: 0.4888 - val_loss: 1.8872
# Epoch 21/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 2.0823e-06 - val_accuracy: 0.5022 - val_loss: 1.8300
# Epoch 22/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 1.6429e-06 - val_accuracy: 0.5291 - val_loss: 1.6878
# Epoch 23/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 7.7411e-07 - val_accuracy: 0.5291 - val_loss: 1.6270
# Epoch 24/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 1.1339e-06 - val_accuracy: 0.5381 - val_loss: 1.5786
# Epoch 25/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 9.1359e-07 - val_accuracy: 0.5471 - val_loss: 1.5107
# Epoch 26/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 9.6241e-07 - val_accuracy: 0.5650 - val_loss: 1.4503
# Epoch 27/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 3.6925e-06 - val_accuracy: 0.5919 - val_loss: 1.3889
# Epoch 28/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 1.0000 - loss: 1.9872e-06 - val_accuracy: 0.6054 - val_loss: 1.3669
# Epoch 29/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 1.0000 - loss: 6.1807e-07 - val_accuracy: 0.6099 - val_loss: 1.3603
# Epoch 30/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 1.0000 - loss: 5.5783e-07 - val_accuracy: 0.6054 - val_loss: 1.3585
# Epoch 31/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 1.0000 - loss: 3.5625e-07 - val_accuracy: 0.6009 - val_loss: 1.3604
# Epoch 32/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 1.0000 - loss: 8.1792e-07 - val_accuracy: 0.6099 - val_loss: 1.3391
# Epoch 33/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 3.3807e-07 - val_accuracy: 0.6099 - val_loss: 1.3385
# Epoch 34/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 2.7314e-07 - val_accuracy: 0.6054 - val_loss: 1.3327
# Epoch 35/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 6.3727e-07 - val_accuracy: 0.6054 - val_loss: 1.3343
# Epoch 36/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 1.0000 - loss: 7.3115e-07 - val_accuracy: 0.6054 - val_loss: 1.3526
# Epoch 37/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 4.6328e-07 - val_accuracy: 0.6099 - val_loss: 1.3556
# Epoch 38/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 3.8953e-07 - val_accuracy: 0.6054 - val_loss: 1.3533
# Epoch 39/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 2.6654e-07 - val_accuracy: 0.6009 - val_loss: 1.3507
# Epoch 40/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 2.2102e-07 - val_accuracy: 0.6054 - val_loss: 1.3372
# Epoch 41/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 3.3900e-07 - val_accuracy: 0.6099 - val_loss: 1.3345
# Epoch 42/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 2.8285e-07 - val_accuracy: 0.6099 - val_loss: 1.3160
# Epoch 43/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 8.6370e-08 - val_accuracy: 0.6054 - val_loss: 1.3244
# Epoch 44/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 1.0000 - loss: 2.6056e-07 - val_accuracy: 0.6009 - val_loss: 1.3437
# Epoch 45/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 3.0076e-07 - val_accuracy: 0.5964 - val_loss: 1.3638
# Epoch 46/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 1.0000 - loss: 3.9731e-07 - val_accuracy: 0.5964 - val_loss: 1.3794
# Epoch 47/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 2.3606e-07 - val_accuracy: 0.5964 - val_loss: 1.3835
# Epoch 48/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 1.0000 - loss: 1.3946e-07 - val_accuracy: 0.5964 - val_loss: 1.3776
# Epoch 49/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 1.4317e-07 - val_accuracy: 0.5964 - val_loss: 1.3769
# Epoch 50/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 1.0000 - loss: 1.4109e-07 - val_accuracy: 0.6009 - val_loss: 1.3511
# Epoch 51/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 1.0000 - loss: 1.0589e-06 - val_accuracy: 0.6143 - val_loss: 1.2941
# Epoch 52/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 1.0000 - loss: 2.7395e-07 - val_accuracy: 0.6278 - val_loss: 1.2594
# Epoch 53/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 1.0000 - loss: 4.4260e-07 - val_accuracy: 0.6233 - val_loss: 1.2588
# Epoch 54/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 1.0000 - loss: 1.7268e-07 - val_accuracy: 0.6323 - val_loss: 1.2504
# Epoch 55/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 7.6717e-07 - val_accuracy: 0.6368 - val_loss: 1.2376
# Epoch 56/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 1.8106e-07 - val_accuracy: 0.6368 - val_loss: 1.2234
# Epoch 57/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 1.3149e-07 - val_accuracy: 0.6368 - val_loss: 1.2266
# Epoch 58/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 1.9833e-07 - val_accuracy: 0.6368 - val_loss: 1.2376
# Epoch 59/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 2.4657e-07 - val_accuracy: 0.6323 - val_loss: 1.2382
# Epoch 60/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 1.0000 - loss: 1.9509e-07 - val_accuracy: 0.6278 - val_loss: 1.2439
# Epoch 61/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 2.1460e-07 - val_accuracy: 0.6233 - val_loss: 1.2494
# Epoch 62/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 1.0000 - loss: 6.2697e-08 - val_accuracy: 0.6233 - val_loss: 1.2532
# Epoch 63/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 1.0000 - loss: 1.2172e-07 - val_accuracy: 0.6233 - val_loss: 1.2608
# Epoch 64/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 1.0000 - loss: 9.3411e-08 - val_accuracy: 0.6233 - val_loss: 1.2698
# Epoch 65/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 1.0000 - loss: 1.9587e-07 - val_accuracy: 0.6278 - val_loss: 1.2628
# Epoch 66/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 2.0050e-07 - val_accuracy: 0.6323 - val_loss: 1.2547
# Epoch 67/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 1.9993e-07 - val_accuracy: 0.6368 - val_loss: 1.2557
# Epoch 68/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 6.1225e-08 - val_accuracy: 0.6323 - val_loss: 1.2511
# Epoch 69/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 9.5145e-08 - val_accuracy: 0.6413 - val_loss: 1.2548
# Epoch 70/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 7.3896e-08 - val_accuracy: 0.6413 - val_loss: 1.2502
# Epoch 71/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 1.5851e-07 - val_accuracy: 0.6323 - val_loss: 1.2535
# Epoch 72/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 1.0000 - loss: 2.6098e-07 - val_accuracy: 0.6323 - val_loss: 1.2521
# Epoch 73/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 1.0000 - loss: 1.8602e-07 - val_accuracy: 0.6323 - val_loss: 1.2561
# Epoch 74/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 1.0000 - loss: 1.0484e-07 - val_accuracy: 0.6278 - val_loss: 1.2573
# Epoch 75/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 1.0000 - loss: 9.3298e-08 - val_accuracy: 0.6278 - val_loss: 1.2575
# Epoch 76/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 1.0000 - loss: 5.0976e-08 - val_accuracy: 0.6278 - val_loss: 1.2609
# Epoch 77/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 1.4447e-07 - val_accuracy: 0.6323 - val_loss: 1.2580
# Epoch 78/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 2.4948e-07 - val_accuracy: 0.6323 - val_loss: 1.2369
# Epoch 79/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 1.1670e-07 - val_accuracy: 0.6323 - val_loss: 1.2417
# Epoch 80/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 1.0000 - loss: 6.6675e-08 - val_accuracy: 0.6323 - val_loss: 1.2434
# Epoch 81/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 1.0000 - loss: 1.0276e-07 - val_accuracy: 0.6278 - val_loss: 1.2825
# Epoch 82/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 1.0000 - loss: 7.1024e-08 - val_accuracy: 0.6233 - val_loss: 1.3312
# Epoch 83/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 8.3597e-08 - val_accuracy: 0.6143 - val_loss: 1.3557
# Epoch 84/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 1.0697e-07 - val_accuracy: 0.6143 - val_loss: 1.3851
# Epoch 85/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 1.3585e-07 - val_accuracy: 0.5874 - val_loss: 1.5318
# Epoch 86/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 7.7421e-08 - val_accuracy: 0.5830 - val_loss: 1.5583
# Epoch 87/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 3.2993e-07 - val_accuracy: 0.5785 - val_loss: 1.6017
# Epoch 88/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 9.7095e-08 - val_accuracy: 0.5740 - val_loss: 1.6191
# Epoch 89/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 1.1895e-07 - val_accuracy: 0.5695 - val_loss: 1.6259
# Epoch 90/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 5.7745e-08 - val_accuracy: 0.5874 - val_loss: 1.5511
# Epoch 91/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 4.7673e-08 - val_accuracy: 0.5964 - val_loss: 1.5425
# Epoch 92/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 2.5268e-07 - val_accuracy: 0.5785 - val_loss: 1.5553
# Epoch 93/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 5.0975e-08 - val_accuracy: 0.5785 - val_loss: 1.5588
# Epoch 94/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 6.4624e-08 - val_accuracy: 0.5785 - val_loss: 1.5628
# Epoch 95/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 1.0000 - loss: 7.6044e-08 - val_accuracy: 0.5830 - val_loss: 1.5589
# Epoch 96/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 1.0000 - loss: 4.8177e-08 - val_accuracy: 0.5830 - val_loss: 1.5582
# Epoch 97/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 1.0000 - loss: 2.8179e-08 - val_accuracy: 0.5830 - val_loss: 1.5637
# Epoch 98/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 1.0000 - loss: 4.5055e-08 - val_accuracy: 0.5830 - val_loss: 1.5646
# Epoch 99/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 1.0000 - loss: 1.1977e-07 - val_accuracy: 0.5919 - val_loss: 1.5621
# Epoch 100/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 7.3764e-08 - val_accuracy: 0.5874 - val_loss: 1.5569

# %%
show_plot(history)

# %%
y_pred = model.predict(x_test)
show_confusion_matrix(y_test, y_pred, CLASS_LIST)
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Средняя точность распознавания:  93%
